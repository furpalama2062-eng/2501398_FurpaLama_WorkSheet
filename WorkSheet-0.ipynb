# %%
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]
Low = []
moderate = []
High = []
for study, entertainment, sleep in time_data:
    if study < 3:
        Low.append(study)
    elif 3 <= study <= 5:
        moderate.append(study)
    else:
        High.append(study)

print("Low:", Low)
print("Moderate:", moderate)
print("High:", High)
# Out:
# Low: [2.5, 1.5, 2.0, 2.5]
# Moderate: [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High: [5.5, 6.0]

# %%
print("Low count:", len(Low))
print("Moderate count:", len(moderate))
print("High count:", len(High))
# Out:
# Low count: 4
# Moderate count: 9
# High count: 2

# %%
study_minutes = [int(study * 60) for study, _, _ in time_data]
print("Study minutes:", study_minutes)
# Out:
# Study minutes: [210, 300, 150, 240, 90, 180, 330, 120, 270, 180, 360, 150, 240, 300, 210]

# %%
study_hours = [s for s, _, _ in time_data]
entertainment_hours = [e for _, e, _ in time_data]
sleep_hours = [sl for _, _, sl in time_data]

def average(nums):
    return sum(nums) / len(nums)

print("Average study:", round(average(study_hours), 2))
print("Average entertainment:", round(average(entertainment_hours), 2))
print("Average sleep:", round(average(sleep_hours), 2))
# Out:
# Average study: 3.7
# Average entertainment: 2.5
# Average sleep: 7.17

# %%
import matplotlib.pyplot as plt

study = [d[0] for d in time_data]
sleep = [d[2] for d in time_data]

plt.scatter(study, sleep, color='blue')
plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("Study vs Sleep Pattern")
plt.show()

# %%
def sum_nested_list(nested_list):
    total = 0
    for element in nested_list:
        if isinstance(element, list):
            total += sum_nested_list(element)
        else:
            total += element
    return total

nested = [1, [2, [3, 4], 5], 6, [7, 8]]
print("Sum of nested list:", sum_nested_list(nested))
# Out:
# Sum of nested list: 36

# %%
def generate_permutations(s):
    if len(s) == 1:
        return [s]

    permutations = []
    for i, char in enumerate(s):
        for perm in generate_permutations(s[:i] + s[i+1:]):
            permutations.append(char + perm)

    return list(set(permutations))  # remove duplicates

print(generate_permutations("abc"))
print(generate_permutations("aab"))
# Out:
# ['acb', 'cba', 'bca', 'abc', 'bac', 'cab']
# ['aab', 'baa', 'aba']

# %%
def get_dir_size(directory):
    size = 0
    for item, value in directory.items():
        if isinstance(value, dict):
            size += get_dir_size(value)
        else:
            size += value
    return size

file_system = {
    "file1": 200,
    "folder1": {
        "file2": 300,
        "file3": 400
    },
    "folder2": {
        "file4": 100
    }
}
print("Total directory size:", get_dir_size(file_system))
# Out:
# Total directory size: 1000

# %%
def coin_change(coins, amount):
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0

    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)

    return dp[amount] if dp[amount] != float('inf') else -1

print("Min coins for 11:", coin_change([1, 2, 5], 11))
# Out:
# Min coins for 11: 3

# %%
def lcs(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n]

print("LCS length:", lcs("abcde", "ace"))
# Out:
# LCS length: 3

# %%
def knapsack(weights, values, capacity):
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(capacity + 1):
            if weights[i-1] <= w:
                dp[i][w] = max(
                    values[i-1] + dp[i-1][w - weights[i-1]],
                    dp[i-1][w]
                )
            else:
                dp[i][w] = dp[i-1][w]

    return dp[n][capacity]

print(knapsack([1, 3, 4, 5], [1, 4, 5, 7], 7))
# Out:
# 9
